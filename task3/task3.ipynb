# %%
import pandas as pd
import numpy as np

df = pd.read_csv("task3.csv")

# %%
df.loc['Sum'] = df.sum()
df_temp = df.loc['Sum']['Anti-Female':'Anti-Mental Disability'].reset_index()

# %%
df_temp.plot(kind='pie', y='Sum', autopct='%1.1f%%', title='Various hates', ylabel='', labeldistance=None, figsize=(9, 6))
# Out:
# <AxesSubplot:title={'center':'Various hates'}>
